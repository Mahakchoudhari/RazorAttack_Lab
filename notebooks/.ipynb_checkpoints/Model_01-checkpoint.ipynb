# %% [markdown]
# ## Phase 1 — Dataset Validation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
DATA_PATH = "../data/razorattacklab_transactions.csv"

df = pd.read_csv(DATA_PATH)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (20000, 24)

# %%
df.head()
# Out:
#   transaction_id user_id merchant_id device_id    ip_id  amount_inr  \
# 0     TXN0000001  U00575       M0173    D02225  IP03001      345.62
# 1     TXN0000002  U04711       M0279    D05691  IP00357    13730.66
# 2     TXN0000003  U00038       M0198    D02340  IP06516     1378.22
# 3     TXN0000004  U01997       M0191    D05995  IP05428     1718.64
# 4     TXN0000005  U03397       M0129    D06141  IP06851      584.50
#
#                timestamp_utc   location payment_method merchant_category  \
# 0  2026-01-01T10:27:00+00:00    Kolkata            UPI     subscriptions
# 1  2026-01-27T04:00:00+00:00     Jaipur     Netbanking              food
# 2  2026-02-24T20:44:00+00:00  Ahmedabad         Wallet         utilities
# 3  2026-02-08T11:40:00+00:00     Jaipur     Netbanking         utilities
# 4  2026-02-23T03:42:00+00:00    Kolkata            UPI         education
#
#    account_age_days  failed_attempts_24h  transactions_1h  transactions_24h  \
# 0               396                    5                1                 6
# 1               909                    0                8                15
# 2               948                    5                5                 5
# 3               908                    0                5                12
# 4                60                    0                1                14
#
#    unique_users_on_device  unique_accounts_on_ip  is_new_device  \
# 0                       2                      2              0
# 1                       1                      1              0
# 2                       2                      1              0
# 3                       1                      1              0
# 4                       4                      1              0
#
#    is_new_location  average_amount_inr  amount_to_average_ratio  is_fraud  \
# 0                0              967.67                    0.357         0
# 1                0             1526.67                    1.781         1
# 2                0              971.21                    1.419         0
# 3                0             1512.60                    1.136         0
# 4                0             1152.14                    0.507         0
#
#      fraud_type  risk_score recommended_decision
# 0          none        6.63                ALLOW
# 1  refund_abuse       97.43                BLOCK
# 2          none       13.43                ALLOW
# 3          none        7.07                ALLOW
# 4          none        1.93                ALLOW

# %%
df.tail()
# Out:
#       transaction_id user_id merchant_id device_id    ip_id  amount_inr  \
# 19995     TXN0019996  U01256       M0244    D01673  IP05044     1280.38
# 19996     TXN0019997  U02798       M0080    D05143  IP02131     3479.72
# 19997     TXN0019998  U02999       M0065    D01708  IP04361      352.33
# 19998     TXN0019999  U01256       M0102    D03448  IP04716      681.34
# 19999     TXN0020000  U00078       M0051    D03487  IP06984      813.29
#
#                    timestamp_utc   location payment_method merchant_category  \
# 19995  2026-02-18T13:42:00+00:00    Lucknow         Wallet            gaming
# 19996  2026-01-19T11:42:00+00:00    Lucknow            UPI         education
# 19997  2026-02-03T06:11:00+00:00    Lucknow         Wallet         ecommerce
# 19998  2026-01-20T12:03:00+00:00     Jaipur         Wallet         education
# 19999  2026-01-17T20:38:00+00:00  Ahmedabad           Card              food
#
#        account_age_days  failed_attempts_24h  transactions_1h  \
# 19995               565                    2                1
# 19996               214                    0                1
# 19997               109                    0                1
# 19998               827                    4                3
# 19999               717                    4                1
#
#        transactions_24h  unique_users_on_device  unique_accounts_on_ip  \
# 19995                17                       1                      3
# 19996                18                       4                      1
# 19997                 4                       1                      3
# 19998                 5                       1                      2
# 19999                20                       1                      4
#
#        is_new_device  is_new_location  average_amount_inr  \
# 19995              0                1              820.21
# 19996              0                0             2310.20
# 19997              0                0              530.24
# 19998              0                0              780.38
# 19999              0                1              397.54
#
#        amount_to_average_ratio  is_fraud fraud_type  risk_score  \
# 19995                    1.561         0       none        8.64
# 19996                    1.506         0       none        6.30
# 19997                    0.664         0       none        2.25
# 19998                    0.873         0       none        9.83
# 19999                    2.046         0       none       25.10
#
#       recommended_decision
# 19995                ALLOW
# 19996                ALLOW
# 19997                ALLOW
# 19998                ALLOW
# 19999                ALLOW

# %%
print("Columns:")
for i, column in enumerate(df.columns, start=1):
    print(f"{i}. {column}")
# Out:
# Columns:
# 1. transaction_id
# 2. user_id
# 3. merchant_id
# 4. device_id
# 5. ip_id
# 6. amount_inr
# 7. timestamp_utc
# 8. location
# 9. payment_method
# 10. merchant_category
# 11. account_age_days
# 12. failed_attempts_24h
# 13. transactions_1h
# 14. transactions_24h
# 15. unique_users_on_device
# 16. unique_accounts_on_ip
# 17. is_new_device
# 18. is_new_location
# 19. average_amount_inr
# 20. amount_to_average_ratio
# 21. is_fraud
# 22. fraud_type
# 23. risk_score
# 24. recommended_decision

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  object
#  1   user_id                  20000 non-null  object
#  2   merchant_id              20000 non-null  object
#  3   device_id                20000 non-null  object
#  4   ip_id                    20000 non-null  object
#  5   amount_inr               20000 non-null  float64
#  6   timestamp_utc            20000 non-null  object
#  7   location                 20000 non-null  object
#  8   payment_method           20000 non-null  object
#  9   merchant_category        20000 non-null  object
#  10  account_age_days         20000 non-null  int64
#  11  failed_attempts_24h      20000 non-null  int64
#  12  transactions_1h          20000 non-null  int64
#  13  transactions_24h         20000 non-null  int64
#  14  unique_users_on_device   20000 non-null  int64
#  15  unique_accounts_on_ip    20000 non-null  int64
#  16  is_new_device            20000 non-null  int64
#  17  is_new_location          20000 non-null  int64
#  18  average_amount_inr       20000 non-null  float64
#  19  amount_to_average_ratio  20000 non-null  float64
#  20  is_fraud                 20000 non-null  int64
#  21  fraud_type               20000 non-null  object
#  22  risk_score               20000 non-null  float64
#  23  recommended_decision     20000 non-null  object
# dtypes: float64(4), int64(9), object(11)
# memory usage: 3.7+ MB

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_report = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_percentage": missing_percentage
})

missing_report.sort_values(
    by="missing_percentage",
    ascending=False
)
# Out:
#                          missing_count  missing_percentage
# transaction_id                       0                 0.0
# user_id                              0                 0.0
# merchant_id                          0                 0.0
# device_id                            0                 0.0
# ip_id                                0                 0.0
# amount_inr                           0                 0.0
# timestamp_utc                        0                 0.0
# location                             0                 0.0
# payment_method                       0                 0.0
# merchant_category                    0                 0.0
# account_age_days                     0                 0.0
# failed_attempts_24h                  0                 0.0
# transactions_1h                      0                 0.0
# transactions_24h                     0                 0.0
# unique_users_on_device               0                 0.0
# unique_accounts_on_ip                0                 0.0
# is_new_device                        0                 0.0
# is_new_location                      0                 0.0
# average_amount_inr                   0                 0.0
# amount_to_average_ratio              0                 0.0
# is_fraud                             0                 0.0
# fraud_type                           0                 0.0
# risk_score                           0                 0.0
# recommended_decision                 0                 0.0

# %%
duplicate_count = df.duplicated().sum()

print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 0

# %%
print(df["is_fraud"].value_counts())
# Out:
# is_fraud
# 0    18447
# 1     1553
# Name: count, dtype: int64

# %%
fraud_percentage = df["is_fraud"].value_counts(normalize=True) * 100

print(fraud_percentage)
# Out:
# is_fraud
# 0    92.235
# 1     7.765
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="is_fraud")

plt.title("Fraud vs Genuine Transactions")
plt.xlabel("Transaction Type")
plt.ylabel("Number of Transactions")

plt.show()

# %%
print(df["fraud_type"].value_counts())
# Out:
# fraud_type
# none                      18447
# emerging_anomaly            376
# rapid_transactions          262
# card_testing                259
# account_takeover            229
# refund_abuse                217
# coordinated_fraud_ring      210
# Name: count, dtype: int64

# %%
print(
    df["fraud_type"].value_counts(normalize=True) * 100
)
# Out:
# fraud_type
# none                      92.235
# emerging_anomaly           1.880
# rapid_transactions         1.310
# card_testing               1.295
# account_takeover           1.145
# refund_abuse               1.085
# coordinated_fraud_ring     1.050
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    y="fraud_type",
    order=df["fraud_type"].value_counts().index
)

plt.title("Fraud Type Distribution")
plt.xlabel("Number of Transactions")
plt.ylabel("Fraud Type")

plt.show()

# %%
fraud_attack = pd.crosstab(
    df["fraud_type"],
    df["is_fraud"]
)

fraud_attack
# Out:
# is_fraud                    0    1
# fraud_type
# account_takeover            0  229
# card_testing                0  259
# coordinated_fraud_ring      0  210
# emerging_anomaly            0  376
# none                    18447    0
# rapid_transactions          0  262
# refund_abuse                0  217

# %%
df["amount_inr"].describe()
# Out:
# count    20000.000000
# mean      2304.933465
# std       6528.249554
# min         13.230000
# 25%        498.392500
# 50%        946.210000
# 75%       1863.005000
# max      89777.680000
# Name: amount_inr, dtype: float64

# %%
df.groupby("is_fraud")["amount_inr"].describe()
# Out:
#             count          mean           std    min     25%      50%  \
# is_fraud
# 0         18447.0   1356.360742   1491.531578  28.64  495.49   906.94
# 1          1553.0  13572.364900  19621.457376  13.23  767.26  5839.26
#
#                75%       max
# is_fraud
# 0          1685.86  38875.01
# 1         17199.90  89777.68

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="is_fraud",
    y="amount_inr"
)

plt.title("Transaction Amount: Fraud vs Genuine")
plt.xlabel("Fraud")
plt.ylabel("Transaction Amount")

plt.show()

# %%
entity_columns = [
    "user_id",
    "merchant_id",
    "device_id",
    "ip_id"
]

for column in entity_columns:
    if column in df.columns:
        print(
            f"{column}: {df[column].nunique()} unique values"
        )
# Out:
# user_id: 4949 unique values
# merchant_id: 300 unique values
# device_id: 6199 unique values
# ip_id: 8053 unique values

# %%
device_user_counts = (
    df.groupby("device_id")["user_id"]
    .nunique()
    .sort_values(ascending=False)
)

print(device_user_counts.head(20))
# Out:
# device_id
# D_RING_07    27
# D_RING_05    23
# D_RING_02    21
# D_RING_01    19
# D_RING_06    17
# D_RING_03    17
# D_RING_08    16
# D_RING_04    16
# D03168       10
# D03003       10
# D03320       10
# D06202       10
# D03302       10
# D03470        9
# D03065        9
# D04430        9
# D03014        9
# D06161        9
# D05408        9
# D05451        9
# Name: user_id, dtype: int64

# %%
suspicious_devices = device_user_counts[
    device_user_counts >= 3
]

print(
    "Devices used by 3+ users:",
    len(suspicious_devices)
)
# Out:
# Devices used by 3+ users: 3835

# %%
ip_user_counts = (
    df.groupby("ip_id")["user_id"]
    .nunique()
    .sort_values(ascending=False)
)

print(ip_user_counts.head(20))
# Out:
# ip_id
# IP_RING_02    31
# IP_RING_04    27
# IP_RING_01    26
# IP_RING_03    23
# IP_RING_05    22
# IP08151       10
# IP03486       10
# IP04907        9
# IP04443        9
# IP00826        9
# IP05460        9
# IP08468        9
# IP06452        9
# IP00385        9
# IP08197        8
# IP02788        8
# IP03857        8
# IP07705        8
# IP04070        8
# IP00189        8
# Name: user_id, dtype: int64

# %%
suspicious_ips = ip_user_counts[
    ip_user_counts >= 5
]

print(
    "IPs used by 5+ users:",
    len(suspicious_ips)
)
# Out:
# IPs used by 5+ users: 631

# %%
print("=" * 50)
print("RAZOR ATTACK LAB - DATA VALIDATION REPORT")
print("=" * 50)

print(f"Total transactions : {len(df):,}")
print(f"Total columns      : {df.shape[1]:,}")
print(f"Duplicate rows     : {df.duplicated().sum():,}")
print(f"Missing values     : {df.isnull().sum().sum():,}")

if "is_fraud" in df.columns:
    fraud_count = df["is_fraud"].sum()
    genuine_count = len(df) - fraud_count

    print(f"Genuine transactions: {genuine_count:,}")
    print(f"Fraud transactions   : {fraud_count:,}")
    print(f"Fraud rate           : {(fraud_count / len(df)) * 100:.2f}%")

if "user_id" in df.columns:
    print(f"Unique users        : {df['user_id'].nunique():,}")

if "device_id" in df.columns:
    print(f"Unique devices      : {df['device_id'].nunique():,}")

if "ip_address" in df.columns:
    print(f"Unique IPs          : {df['ip_address'].nunique():,}")

if "card_id" in df.columns:
    print(f"Unique cards        : {df['card_id'].nunique():,}")

print("=" * 50)
# Out:
# ==================================================
# RAZOR ATTACK LAB - DATA VALIDATION REPORT
# ==================================================
# Total transactions : 20,000
# Total columns      : 24
# Duplicate rows     : 0
# Missing values     : 0
# Genuine transactions: 18,447
# Fraud transactions   : 1,553
# Fraud rate           : 7.76%
# Unique users        : 4,949
# Unique devices      : 6,199
# ==================================================
